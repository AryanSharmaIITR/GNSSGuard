# %%
import pandas as pd

# %%
df_tr=pd.read_csv("../dataset/train_ch1.csv")
df_va=pd.read_csv("../dataset/val_ch1.csv")

# %%
df_tr.batch_id.value_counts()
# Out:
# batch_id
# 0       101
# 1       101
# 2       101
# 3       101
# 4       101
#        ...
# 4511    101
# 4512    101
# 4513    101
# 4514    101
# 4515    101
# Name: count, Length: 4516, dtype: int64

# %%
df_tr.groupby("batch_id").spoofed.value_counts()
# Out:
# batch_id  spoofed
# 0         0          100
#           1            1
# 1         0           99
#           1            2
# 2         0           98
#                     ...
# 4511      0          101
# 4512      0          101
# 4513      0          101
# 4514      0          101
# 4515      0          101
# Name: count, Length: 4616, dtype: int64
